# %%
# %matplotlib inline

# %%
import os
import sys
import json
import datetime
from collections import Counter
from __future__ import print_function

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
sys.path.append(r"C:\Users\Max\Documents\GitHub\SummonersGift\Python")
import dataLoading

# %%
matchesPath = r'C:\Users\Max\Documents\GitHub\SummonersGift\Data\Matches\AprilData'
summonerPath = r'C:\Users\Max\Documents\GitHub\SummonersGift\Data\Summoners\AprilData'
df = pd.read_pickle(matchesPath + r"\Serialised\lightMatches2.pickle")
df.head()
# Out:
#    mapId  matchCreation     matchId matchVersion platformId         queueType  \
# 0     11  1429041884769  2066637637    5.7.0.275       EUW1  NORMAL_5x5_BLIND
# 1     11  1429041884770  2066637638    5.7.0.275       EUW1  NORMAL_5x5_BLIND
# 2     11  1429041884774  2066637640    5.7.0.275       EUW1  NORMAL_5x5_BLIND
# 3     11  1429041884808  2066637643    5.7.0.275       EUW1  NORMAL_5x5_BLIND
# 4     11  1429041884822  2066637644    5.7.0.275       EUW1  NORMAL_5x5_BLIND
#
#   region
# 0    EUW
# 1    EUW
# 2    EUW
# 3    EUW
# 4    EUW

# %%
df = dataLoading.prepareCleanRanked(matchesPath + r"\Serialised\lightMatches2.pickle", matchesPath, summonerPath)

# %%
df3 = df2.merge(rs, "inner", left_on=["matchId", "teamId"], right_on=["matchId", "teamId"])
df3["csAt10"] = df3.timeline.apply(lambda x:  x.get("creepsPerMinDeltas", {"zeroToTen": None})["zeroToTen"])
df3["csAt10"] = df3["csAt10"] * 10.0

dataLoading.sumCats(df3)

dfc = df3[(df3.role.isin(["SOLO","DUO_CARRY"])) & (df3.isStandardLanesGame)]
    
dfc.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-77af63373bff> in <module>()
# ----> 1 df3 = df2.merge(rs, "inner", left_on=["matchId", "teamId"], right_on=["matchId", "teamId"])
#       2 df3["csAt10"] = df3.timeline.apply(lambda x:  x.get("creepsPerMinDeltas", {"zeroToTen": None})["zeroToTen"])
#       3 df3["csAt10"] = df3["csAt10"] * 10.0
#       4
#       5 dataLoading.sumCats(df3)
#
# NameError: name 'df2' is not defined

# %%
cs = dfc.groupby(["tier", "division", "lane"])["csAt10"].median().unstack()
p = cs.plot(kind="bar", title="CS at 10 minutes", figsize=(15,15), stacked=False)
p.axhline(y=dataLoading.laneCsAtMinute(10.0),c="purple",linewidth=1.0,zorder=0, linestyle="--", label="Total Lane Minions")
p.legend()

# %%
dfc.isStandardLanesGame.value_counts()

# %%
standardGames = rs[(rs.isStandardLanesGame)].drop_duplicates("matchId")
stLen = len(standardGames)
print(stLen)
print(stLen * 6)
print(len(dfc))
#standardGames[~standardGames.matchId.isin(dfc.matchId)]#.dropna(how = 'all')
(dfc.groupby("matchId").apply(np.size) / 34.0).sort(inplace=False)

# %%
e = df[(df.matchId.isin(np.array([2067110211,2066842844,2067041342,2066721002,2067047792])))]
f = pd.concat([e, e.timeline.apply(pd.Series)], axis=1)
f

# %%
objCols = dfc.dtypes[dfc.dtypes == object]

# %%
dfc[objCols.index]
# Out:
#                                                     stats  \
# 0       {u'item1': 3031, u'totalPlayerScore': 0, u'unr...
# 1       {u'item1': 3089, u'totalPlayerScore': 0, u'unr...
# 2       {u'item1': 3074, u'totalPlayerScore': 0, u'unr...
# 5       {u'item1': 3089, u'totalPlayerScore': 0, u'unr...
# 6       {u'item1': 3035, u'totalPlayerScore': 0, u'unr...
# 7       {u'item1': 3087, u'totalPlayerScore': 0, u'unr...
# 10      {u'item1': 3087, u'totalPlayerScore': 0, u'unr...
# 11      {u'item1': 3110, u'totalPlayerScore': 0, u'unr...
# 12      {u'item1': 3252, u'totalPlayerScore': 0, u'unr...
# 16      {u'item1': 3083, u'totalPlayerScore': 0, u'unr...
# 17      {u'item1': 3089, u'totalPlayerScore': 0, u'unr...
# 19      {u'item1': 3031, u'totalPlayerScore': 0, u'unr...
# 20      {u'item1': 3031, u'totalPlayerScore': 0, u'unr...
# 22      {u'item1': 3020, u'totalPlayerScore': 0, u'unr...
# 24      {u'item1': 3083, u'totalPlayerScore': 0, u'unr...
# 25      {u'item1': 3006, u'totalPlayerScore': 0, u'unr...
# 27      {u'item1': 1057, u'totalPlayerScore': 0, u'unr...
# 29      {u'item1': 1054, u'totalPlayerScore': 0, u'unr...
# 30      {u'item1': 3087, u'totalPlayerScore': 0, u'unr...
# 32      {u'item1': 3512, u'totalPlayerScore': 0, u'unr...
# 33      {u'item1': 3174, u'totalPlayerScore': 0, u'unr...
# 35      {u'item1': 3031, u'totalPlayerScore': 0, u'unr...
# 36      {u'item1': 2041, u'totalPlayerScore': 0, u'unr...
# 39      {u'item1': 1026, u'totalPlayerScore': 0, u'unr...
# 50      {u'item1': 3031, u'totalPlayerScore': 0, u'unr...
# 51      {u'item1': 2003, u'totalPlayerScore': 0, u'unr...
# 53      {u'item1': 3078, u'totalPlayerScore': 0, u'unr...
# 55      {u'item1': 3153, u'totalPlayerScore': 0, u'unr...
# 56      {u'item1': 3083, u'totalPlayerScore': 0, u'unr...
# 57      {u'item1': 3157, u'totalPlayerScore': 0, u'unr...
# ...                                                   ...
# 553592  {u'item1': 3001, u'totalPlayerScore': 0, u'unr...
# 553593  {u'item1': 2003, u'totalPlayerScore': 0, u'unr...
# 553594  {u'item1': 2003, u'totalPlayerScore': 0, u'unr...
# 553601  {u'item1': 2003, u'totalPlayerScore': 0, u'unr...
# 553602  {u'item1': 1053, u'totalPlayerScore': 0, u'unr...
# 553604  {u'item1': 3165, u'totalPlayerScore': 0, u'unr...
# 553607  {u'item1': 3031, u'totalPlayerScore': 0, u'unr...
# 553608  {u'item1': 3087, u'totalPlayerScore': 0, u'unr...
# 553609  {u'item1': 3065, u'totalPlayerScore': 0, u'unr...
# 553611  {u'item1': 3022, u'totalPlayerScore': 0, u'unr...
# 553612  {u'item1': 3001, u'totalPlayerScore': 0, u'unr...
# 553614  {u'item1': 3078, u'totalPlayerScore': 0, u'unr...
# 553631  {u'item1': 3275, u'totalPlayerScore': 0, u'unr...
# 553632  {u'item1': 3027, u'totalPlayerScore': 0, u'unr...
# 553634  {u'item1': 3153, u'totalPlayerScore': 0, u'unr...
# 553635  {u'item1': 3020, u'totalPlayerScore': 0, u'unr...
# 553637  {u'item1': 3087, u'totalPlayerScore': 0, u'unr...
# 553638  {u'item1': 1057, u'totalPlayerScore': 0, u'unr...
# 553646  {u'item1': 3087, u'totalPlayerScore': 0, u'unr...
# 553647  {u'item1': 3165, u'totalPlayerScore': 0, u'unr...
# 553649  {u'item1': 3110, u'totalPlayerScore': 0, u'unr...
# 553653  {u'item1': 1029, u'totalPlayerScore': 0, u'unr...
# 553654  {u'item1': 3072, u'totalPlayerScore': 0, u'unr...
# 553656  {u'item1': 3265, u'totalPlayerScore': 0, u'unr...
# 553658  {u'item1': 3165, u'totalPlayerScore': 0, u'unr...
# 553659  {u'item1': 2003, u'totalPlayerScore': 0, u'unr...
# 553662  {u'item1': 2003, u'totalPlayerScore': 0, u'unr...
# 553667  {u'item1': 3031, u'totalPlayerScore': 0, u'unr...
# 553669  {u'item1': 3165, u'totalPlayerScore': 0, u'unr...
# 553670  {u'item1': 3068, u'totalPlayerScore': 0, u'unr...
#
#                                                  timeline  \
# 0       {u'lane': u'BOTTOM', u'csDiffPerMinDeltas': {u...
# 1       {u'lane': u'MIDDLE', u'csDiffPerMinDeltas': {u...
# 2       {u'lane': u'TOP', u'csDiffPerMinDeltas': {u'th...
# 5       {u'lane': u'MIDDLE', u'csDiffPerMinDeltas': {u...
# 6       {u'lane': u'TOP', u'csDiffPerMinDeltas': {u'th...
# 7       {u'lane': u'BOTTOM', u'csDiffPerMinDeltas': {u...
# 10      {u'lane': u'MIDDLE', u'csDiffPerMinDeltas': {u...
# 11      {u'lane': u'TOP', u'csDiffPerMinDeltas': {u'th...
# 12      {u'lane': u'BOTTOM', u'csDiffPerMinDeltas': {u...
# 16      {u'lane': u'TOP', u'csDiffPerMinDeltas': {u'ze...
# 17      {u'lane': u'MIDDLE', u'csDiffPerMinDeltas': {u...
# 19      {u'lane': u'BOTTOM', u'csDiffPerMinDeltas': {u...
# 20      {u'lane': u'BOTTOM', u'csDiffPerMinDeltas': {u...
# 22      {u'lane': u'MIDDLE', u'csDiffPerMinDeltas': {u...
# 24      {u'lane': u'TOP', u'csDiffPerMinDeltas': {u'ze...
# 25      {u'lane': u'BOTTOM', u'csDiffPerMinDeltas': {u...
# 27      {u'lane': u'MIDDLE', u'csDiffPerMinDeltas': {u...
# 29      {u'lane': u'TOP', u'csDiffPerMinDeltas': {u'ze...
# 30      {u'lane': u'BOTTOM', u'csDiffPerMinDeltas': {u...
# 32      {u'lane': u'TOP', u'csDiffPerMinDeltas': {u'th...
# 33      {u'lane': u'MIDDLE', u'csDiffPerMinDeltas': {u...
# 35      {u'lane': u'BOTTOM', u'csDiffPerMinDeltas': {u...
# 36      {u'lane': u'TOP', u'csDiffPerMinDeltas': {u'tw...
# 39      {u'lane': u'MIDDLE', u'csDiffPerMinDeltas': {u...
# 50      {u'lane': u'BOTTOM', u'csDiffPerMinDeltas': {u...
# 51      {u'lane': u'MIDDLE', u'csDiffPerMinDeltas': {u...
# 53      {u'lane': u'TOP', u'csDiffPerMinDeltas': {u'ze...
# 55      {u'lane': u'BOTTOM', u'csDiffPerMinDeltas': {u...
# 56      {u'lane': u'TOP', u'csDiffPerMinDeltas': {u'tw...
# 57      {u'lane': u'MIDDLE', u'csDiffPerMinDeltas': {u...
# ...                                                   ...
# 553592  {u'lane': u'MIDDLE', u'csDiffPerMinDeltas': {u...
# 553593  {u'lane': u'BOTTOM', u'csDiffPerMinDeltas': {u...
# 553594  {u'lane': u'TOP', u'csDiffPerMinDeltas': {u'ze...
# 553601  {u'lane': u'TOP', u'csDiffPerMinDeltas': {u'ze...
# 553602  {u'lane': u'BOTTOM', u'csDiffPerMinDeltas': {u...
# 553604  {u'lane': u'MIDDLE', u'csDiffPerMinDeltas': {u...
# 553607  {u'lane': u'MIDDLE', u'csDiffPerMinDeltas': {u...
# 553608  {u'lane': u'BOTTOM', u'csDiffPerMinDeltas': {u...
# 553609  {u'lane': u'TOP', u'csDiffPerMinDeltas': {u'th...
# 553611  {u'lane': u'TOP', u'csDiffPerMinDeltas': {u'th...
# 553612  {u'lane': u'MIDDLE', u'csDiffPerMinDeltas': {u...
# 553614  {u'lane': u'BOTTOM', u'csDiffPerMinDeltas': {u...
# 553631  {u'lane': u'TOP', u'csDiffPerMinDeltas': {u'th...
# 553632  {u'lane': u'MIDDLE', u'csDiffPerMinDeltas': {u...
# 553634  {u'lane': u'BOTTOM', u'csDiffPerMinDeltas': {u...
# 553635  {u'lane': u'MIDDLE', u'csDiffPerMinDeltas': {u...
# 553637  {u'lane': u'BOTTOM', u'csDiffPerMinDeltas': {u...
# 553638  {u'lane': u'TOP', u'csDiffPerMinDeltas': {u'tw...
# 553646  {u'lane': u'BOTTOM', u'csDiffPerMinDeltas': {u...
# 553647  {u'lane': u'MIDDLE', u'csDiffPerMinDeltas': {u...
# 553649  {u'lane': u'TOP', u'csDiffPerMinDeltas': {u'th...
# 553653  {u'lane': u'MIDDLE', u'csDiffPerMinDeltas': {u...
# 553654  {u'lane': u'BOTTOM', u'csDiffPerMinDeltas': {u...
# 553656  {u'lane': u'TOP', u'csDiffPerMinDeltas': {u'th...
# 553658  {u'lane': u'MIDDLE', u'csDiffPerMinDeltas': {u...
# 553659  {u'lane': u'TOP', u'csDiffPerMinDeltas': {u'ze...
# 553662  {u'lane': u'BOTTOM', u'csDiffPerMinDeltas': {u...
# 553667  {u'lane': u'BOTTOM', u'csDiffPerMinDeltas': {u...
# 553669  {u'lane': u'MIDDLE', u'csDiffPerMinDeltas': {u...
# 553670  {u'lane': u'TOP', u'csDiffPerMinDeltas': {u'th...
#
#                                        creepsPerMinDeltas  \
# 0       {u'thirtyToEnd': 7.9, u'twentyToThirty': 5.1, ...
# 1       {u'thirtyToEnd': 6.0, u'twentyToThirty': 3.1, ...
# 2       {u'thirtyToEnd': 6.8, u'twentyToThirty': 7.1, ...
# 5       {u'thirtyToEnd': 5.2, u'twentyToThirty': 4.5, ...
# 6       {u'thirtyToEnd': 5.2, u'twentyToThirty': 7.3, ...
# 7       {u'thirtyToEnd': 5.4, u'twentyToThirty': 5.4, ...
# 10      {u'thirtyToEnd': 5.7, u'twentyToThirty': 8.4, ...
# 11      {u'thirtyToEnd': 3.8, u'twentyToThirty': 5.0, ...
# 12      {u'thirtyToEnd': 5.1, u'twentyToThirty': 6.5, ...
# 16               {u'zeroToTen': 3.8, u'tenToTwenty': 5.6}
# 17               {u'zeroToTen': 5.4, u'tenToTwenty': 7.5}
# 19               {u'zeroToTen': 6.3, u'tenToTwenty': 6.5}
# 20               {u'zeroToTen': 6.8, u'tenToTwenty': 8.3}
# 22               {u'zeroToTen': 5.3, u'tenToTwenty': 6.8}
# 24               {u'zeroToTen': 5.9, u'tenToTwenty': 6.1}
# 25               {u'zeroToTen': 6.2, u'tenToTwenty': 6.5}
# 27               {u'zeroToTen': 6.9, u'tenToTwenty': 4.8}
# 29               {u'zeroToTen': 5.5, u'tenToTwenty': 8.0}
# 30      {u'thirtyToEnd': 3.8, u'twentyToThirty': 8.5, ...
# 32      {u'thirtyToEnd': 7.6, u'twentyToThirty': 8.9, ...
# 33      {u'thirtyToEnd': 4.8, u'twentyToThirty': 4.8, ...
# 35      {u'twentyToThirty': 4.4, u'zeroToTen': 7.5, u'...
# 36      {u'twentyToThirty': 7.1, u'zeroToTen': 6.2, u'...
# 39      {u'twentyToThirty': 5.0, u'zeroToTen': 5.0, u'...
# 50               {u'zeroToTen': 7.2, u'tenToTwenty': 6.6}
# 51               {u'zeroToTen': 3.9, u'tenToTwenty': 3.6}
# 53               {u'zeroToTen': 6.8, u'tenToTwenty': 9.3}
# 55      {u'twentyToThirty': 5.5, u'zeroToTen': 5.9, u'...
# 56      {u'twentyToThirty': 5.2, u'zeroToTen': 5.3, u'...
# 57      {u'twentyToThirty': 3.9, u'zeroToTen': 5.9, u'...
# ...                                                   ...
# 553592           {u'zeroToTen': 3.5, u'tenToTwenty': 5.0}
# 553593           {u'zeroToTen': 3.4, u'tenToTwenty': 6.1}
# 553594           {u'zeroToTen': 4.6, u'tenToTwenty': 4.5}
# 553601           {u'zeroToTen': 5.1, u'tenToTwenty': 4.4}
# 553602           {u'zeroToTen': 3.8, u'tenToTwenty': 4.2}
# 553604           {u'zeroToTen': 3.3, u'tenToTwenty': 4.5}
# 553607  {u'thirtyToEnd': 5.4, u'twentyToThirty': 6.3, ...
# 553608  {u'thirtyToEnd': 4.8, u'twentyToThirty': 7.8, ...
# 553609  {u'thirtyToEnd': 2.0, u'twentyToThirty': 6.4, ...
# 553611  {u'thirtyToEnd': 3.2, u'twentyToThirty': 2.2, ...
# 553612  {u'thirtyToEnd': 0.0, u'twentyToThirty': 2.4, ...
# 553614  {u'thirtyToEnd': 7.4, u'twentyToThirty': 7.5, ...
# 553631  {u'thirtyToEnd': 5.7, u'twentyToThirty': 8.6, ...
# 553632  {u'thirtyToEnd': 3.2, u'twentyToThirty': 1.8, ...
# 553634  {u'thirtyToEnd': 6.45, u'twentyToThirty': 6.2,...
# 553635  {u'twentyToThirty': 3.5, u'zeroToTen': 5.2, u'...
# 553637  {u'twentyToThirty': 5.8, u'zeroToTen': 7.5, u'...
# 553638  {u'twentyToThirty': 1.7, u'zeroToTen': 5.2, u'...
# 553646  {u'thirtyToEnd': 2.2, u'twentyToThirty': 4.8, ...
# 553647  {u'thirtyToEnd': 3.3, u'twentyToThirty': 2.0, ...
# 553649  {u'thirtyToEnd': 4.9, u'twentyToThirty': 2.8, ...
# 553653  {u'thirtyToEnd': 6.2, u'twentyToThirty': 3.7, ...
# 553654  {u'thirtyToEnd': 4.4, u'twentyToThirty': 3.5, ...
# 553656  {u'thirtyToEnd': 1.0, u'twentyToThirty': 6.3, ...
# 553658           {u'zeroToTen': 5.2, u'tenToTwenty': 5.1}
# 553659           {u'zeroToTen': 6.0, u'tenToTwenty': 6.6}
# 553662           {u'zeroToTen': 4.0, u'tenToTwenty': 5.6}
# 553667  {u'thirtyToEnd': 3.4, u'twentyToThirty': 6.0, ...
# 553669  {u'thirtyToEnd': 4.0, u'twentyToThirty': 3.9, ...
# 553670  {u'thirtyToEnd': 0.9, u'twentyToThirty': 9.9, ...
#
#                                        csDiffPerMinDeltas  \
# 0       {u'thirtyToEnd': 1.35, u'twentyToThirty': -1.2...
# 1       {u'thirtyToEnd': 0.3, u'twentyToThirty': -5.3,...
# 2       {u'thirtyToEnd': 3.0, u'twentyToThirty': 2.1, ...
# 5       {u'thirtyToEnd': 0.4, u'twentyToThirty': -2.8,...
# 6       {u'thirtyToEnd': 3.2, u'twentyToThirty': 6.0, ...
# 7       {u'thirtyToEnd': -1.5, u'twentyToThirty': -1.2...
# 10      {u'thirtyToEnd': -0.3, u'twentyToThirty': 5.3,...
# 11      {u'thirtyToEnd': -3.0, u'twentyToThirty': -2.1...
# 12      {u'thirtyToEnd': -1.35, u'twentyToThirty': 1.2...
# 16             {u'zeroToTen': -3.0, u'tenToTwenty': -2.5}
# 17               {u'zeroToTen': 1.8, u'tenToTwenty': 4.7}
# 19               {u'zeroToTen': 0.8, u'tenToTwenty': 0.8}
# 20            {u'zeroToTen': -0.15, u'tenToTwenty': 0.95}
# 22             {u'zeroToTen': -0.7, u'tenToTwenty': -0.6}
# 24             {u'zeroToTen': -1.9, u'tenToTwenty': -5.0}
# 25              {u'zeroToTen': -0.6, u'tenToTwenty': 0.5}
# 27               {u'zeroToTen': 1.3, u'tenToTwenty': 1.6}
# 29             {u'zeroToTen': -2.2, u'tenToTwenty': -1.3}
# 30      {u'thirtyToEnd': -1.9, u'twentyToThirty': 0.85...
# 32      {u'thirtyToEnd': 2.0, u'twentyToThirty': -1.6,...
# 33      {u'thirtyToEnd': -1.4, u'twentyToThirty': -0.7...
# 35      {u'twentyToThirty': -1.2, u'zeroToTen': 0.05, ...
# 36      {u'twentyToThirty': 3.7, u'zeroToTen': 0.2, u'...
# 39      {u'twentyToThirty': 0.4, u'zeroToTen': 2.8, u'...
# 50            {u'zeroToTen': -0.25, u'tenToTwenty': -1.2}
# 51             {u'zeroToTen': -2.1, u'tenToTwenty': -1.3}
# 53               {u'zeroToTen': 2.4, u'tenToTwenty': 4.6}
# 55      {u'twentyToThirty': 1.05, u'zeroToTen': 0.45, ...
# 56      {u'twentyToThirty': -3.0, u'zeroToTen': -1.3, ...
# 57      {u'twentyToThirty': -1.7, u'zeroToTen': -0.3, ...
# ...                                                   ...
# 553592         {u'zeroToTen': -2.0, u'tenToTwenty': -0.7}
# 553593        {u'zeroToTen': -1.25, u'tenToTwenty': -1.8}
# 553594         {u'zeroToTen': -1.8, u'tenToTwenty': -1.8}
# 553601          {u'zeroToTen': 2.1, u'tenToTwenty': -0.6}
# 553602          {u'zeroToTen': -0.1, u'tenToTwenty': 1.6}
# 553604          {u'zeroToTen': -0.3, u'tenToTwenty': 0.6}
# 553607  {u'thirtyToEnd': 0.4, u'twentyToThirty': 1.0, ...
# 553608  {u'thirtyToEnd': -1.9, u'twentyToThirty': 1.65...
# 553609  {u'thirtyToEnd': -0.8, u'twentyToThirty': 2.9,...
# 553611  {u'thirtyToEnd': -1.2, u'twentyToThirty': -2.0...
# 553612  {u'thirtyToEnd': -6.8, u'twentyToThirty': -1.5...
# 553614  {u'thirtyToEnd': -0.05, u'twentyToThirty': -0....
# 553631  {u'thirtyToEnd': 3.0, u'twentyToThirty': 5.0, ...
# 553632  {u'thirtyToEnd': 0.5, u'twentyToThirty': -2.6,...
# 553634  {u'thirtyToEnd': 0.325, u'twentyToThirty': 0.2...
# 553635  {u'twentyToThirty': -3.1, u'zeroToTen': -0.1, ...
# 553637  {u'twentyToThirty': 0.2, u'zeroToTen': 0.45, u...
# 553638  {u'twentyToThirty': -0.7, u'zeroToTen': 1.7, u...
# 553646  {u'thirtyToEnd': -2.45, u'twentyToThirty': 0.3...
# 553647  {u'thirtyToEnd': -2.7, u'twentyToThirty': -2.5...
# 553649  {u'thirtyToEnd': 1.5, u'twentyToThirty': 0.2, ...
# 553653  {u'thirtyToEnd': 3.0, u'twentyToThirty': -0.2,...
# 553654  {u'thirtyToEnd': -3.7, u'twentyToThirty': -1.9...
# 553656  {u'thirtyToEnd': -0.6, u'twentyToThirty': 4.2,...
# 553658         {u'zeroToTen': -1.9, u'tenToTwenty': -1.4}
# 553659         {u'zeroToTen': -0.6, u'tenToTwenty': -0.1}
# 553662        {u'zeroToTen': -1.15, u'tenToTwenty': -0.6}
# 553667  {u'thirtyToEnd': -3.33066907388e-16, u'twentyT...
# 553669  {u'thirtyToEnd': 1.2, u'twentyToThirty': 1.6, ...
# 553670  {u'thirtyToEnd': -1.4, u'twentyToThirty': 6.3,...
#
#                               damageTakenDiffPerMinDeltas  \
# 0       {u'thirtyToEnd': -374.9, u'twentyToThirty': 48...
# 1       {u'thirtyToEnd': 95.3, u'twentyToThirty': -206...
# 2       {u'thirtyToEnd': -896.1, u'twentyToThirty': -1...
# 5       {u'thirtyToEnd': -89.4, u'twentyToThirty': 140...
# 6       {u'thirtyToEnd': -301.4, u'twentyToThirty': 70...
# 7       {u'thirtyToEnd': 465.6, u'twentyToThirty': 50....
# 10      {u'thirtyToEnd': -95.3, u'twentyToThirty': 206...
# 11      {u'thirtyToEnd': 896.1, u'twentyToThirty': 103...
# 12      {u'thirtyToEnd': 374.9, u'twentyToThirty': -48...
# 16          {u'zeroToTen': 230.8, u'tenToTwenty': -165.9}
# 17           {u'zeroToTen': -3.9, u'tenToTwenty': -303.9}
# 19         {u'zeroToTen': -69.2, u'tenToTwenty': -173.15}
# 20            {u'zeroToTen': -9.8, u'tenToTwenty': 26.05}
# 22            {u'zeroToTen': -57.4, u'tenToTwenty': 64.3}
# 24           {u'zeroToTen': -18.8, u'tenToTwenty': 146.9}
# 25            {u'zeroToTen': 2.4, u'tenToTwenty': -156.0}
# 27            {u'zeroToTen': 60.4, u'tenToTwenty': -45.2}
# 29           {u'zeroToTen': 224.2, u'tenToTwenty': -80.3}
# 30      {u'thirtyToEnd': -744.9, u'twentyToThirty': -1...
# 32      {u'thirtyToEnd': -408.6, u'twentyToThirty': -2...
# 33      {u'thirtyToEnd': -408.6, u'twentyToThirty': -2...
# 35      {u'twentyToThirty': -305.3, u'zeroToTen': -95....
# 36      {u'twentyToThirty': 275.2, u'zeroToTen': 205.5...
# 39      {u'twentyToThirty': -217.0, u'zeroToTen': -31....
# 50          {u'zeroToTen': -25.4, u'tenToTwenty': 102.35}
# 51           {u'zeroToTen': 67.5, u'tenToTwenty': -325.2}
# 53           {u'zeroToTen': -30.1, u'tenToTwenty': -50.0}
# 55      {u'twentyToThirty': -233.5, u'zeroToTen': 23.6...
# 56      {u'twentyToThirty': 1044.2, u'zeroToTen': 187....
# 57      {u'twentyToThirty': -203.0, u'zeroToTen': -237...
# ...                                                   ...
# 553592       {u'zeroToTen': 40.9, u'tenToTwenty': -243.4}
# 553593       {u'zeroToTen': 9.85, u'tenToTwenty': -169.9}
# 553594       {u'zeroToTen': 185.1, u'tenToTwenty': 182.8}
# 553601     {u'zeroToTen': -143.6, u'tenToTwenty': -282.0}
# 553602       {u'zeroToTen': 80.1, u'tenToTwenty': -221.7}
# 553604        {u'zeroToTen': 1.8, u'tenToTwenty': -276.4}
# 553607  {u'thirtyToEnd': -554.2, u'twentyToThirty': -4...
# 553608  {u'thirtyToEnd': -321.5, u'twentyToThirty': -1...
# 553609  {u'thirtyToEnd': 206.2, u'twentyToThirty': 611...
# 553611  {u'thirtyToEnd': -657.2, u'twentyToThirty': -5...
# 553612  {u'thirtyToEnd': -921.7, u'twentyToThirty': -2...
# 553614  {u'thirtyToEnd': -110.35, u'twentyToThirty': 2...
# 553631  {u'thirtyToEnd': -249.75, u'twentyToThirty': -...
# 553632  {u'thirtyToEnd': 227.5, u'twentyToThirty': 185...
# 553634  {u'thirtyToEnd': 40.975, u'twentyToThirty': -2...
# 553635  {u'twentyToThirty': 526.4, u'zeroToTen': -8.8,...
# 553637  {u'twentyToThirty': 2.9, u'zeroToTen': -96.65,...
# 553638  {u'twentyToThirty': 542.5, u'zeroToTen': -187....
# 553646  {u'thirtyToEnd': 327.65, u'twentyToThirty': -1...
# 553647  {u'thirtyToEnd': 109.8, u'twentyToThirty': -43...
# 553649  {u'thirtyToEnd': 959.5, u'twentyToThirty': 795...
# 553653  {u'thirtyToEnd': -12.2, u'twentyToThirty': 249...
# 553654  {u'thirtyToEnd': 496.1, u'twentyToThirty': -22...
# 553656  {u'thirtyToEnd': 177.0, u'twentyToThirty': 149...
# 553658       {u'zeroToTen': 138.2, u'tenToTwenty': 243.3}
# 553659        {u'zeroToTen': 75.0, u'tenToTwenty': -97.1}
# 553662          {u'zeroToTen': 6.5, u'tenToTwenty': -2.3}
# 553667  {u'thirtyToEnd': 458.2, u'twentyToThirty': 55....
# 553669  {u'thirtyToEnd': 185.2, u'twentyToThirty': -28...
# 553670  {u'thirtyToEnd': 1182.9, u'twentyToThirty': 25...
#
#                                   damageTakenPerMinDeltas  \
# 0       {u'thirtyToEnd': 824.5, u'twentyToThirty': 104...
# 1       {u'thirtyToEnd': 842.7, u'twentyToThirty': 905...
# 2       {u'thirtyToEnd': 1117.5, u'twentyToThirty': 10...
# 5       {u'thirtyToEnd': 862.8, u'twentyToThirty': 700...
# 6       {u'thirtyToEnd': 1294.8, u'twentyToThirty': 10...
# 7       {u'thirtyToEnd': 1290.0, u'twentyToThirty': 10...
# 10      {u'thirtyToEnd': 747.4, u'twentyToThirty': 111...
# 11      {u'thirtyToEnd': 2013.6, u'twentyToThirty': 11...
# 12      {u'thirtyToEnd': 972.6, u'twentyToThirty': 753...
# 16           {u'zeroToTen': 691.4, u'tenToTwenty': 923.1}
# 17           {u'zeroToTen': 434.3, u'tenToTwenty': 549.8}
# 19           {u'zeroToTen': 279.5, u'tenToTwenty': 547.6}
# 20           {u'zeroToTen': 161.5, u'tenToTwenty': 488.0}
# 22           {u'zeroToTen': 287.0, u'tenToTwenty': 549.3}
# 24          {u'zeroToTen': 430.5, u'tenToTwenty': 1158.5}
# 25           {u'zeroToTen': 213.5, u'tenToTwenty': 416.1}
# 27           {u'zeroToTen': 233.3, u'tenToTwenty': 557.1}
# 29           {u'zeroToTen': 604.9, u'tenToTwenty': 847.0}
# 30      {u'thirtyToEnd': 782.2, u'twentyToThirty': 756...
# 32      {u'thirtyToEnd': 882.2, u'twentyToThirty': 951...
# 33      {u'thirtyToEnd': 964.8, u'twentyToThirty': 978...
# 35      {u'twentyToThirty': 544.7, u'zeroToTen': 102.5...
# 36      {u'twentyToThirty': 1237.3, u'zeroToTen': 601....
# 39      {u'twentyToThirty': 461.2, u'zeroToTen': 418.2...
# 50           {u'zeroToTen': 233.6, u'tenToTwenty': 454.3}
# 51           {u'zeroToTen': 626.9, u'tenToTwenty': 739.3}
# 53           {u'zeroToTen': 385.3, u'tenToTwenty': 513.6}
# 55      {u'twentyToThirty': 798.4, u'zeroToTen': 376.2...
# 56      {u'twentyToThirty': 2144.4, u'zeroToTen': 591....
# 57      {u'twentyToThirty': 982.1, u'zeroToTen': 212.1...
# ...                                                   ...
# 553592       {u'zeroToTen': 296.5, u'tenToTwenty': 596.6}
# 553593       {u'zeroToTen': 383.7, u'tenToTwenty': 507.1}
# 553594      {u'zeroToTen': 420.6, u'tenToTwenty': 1040.5}
# 553601       {u'zeroToTen': 265.7, u'tenToTwenty': 514.3}
# 553602       {u'zeroToTen': 294.4, u'tenToTwenty': 510.4}
# 553604       {u'zeroToTen': 224.0, u'tenToTwenty': 380.5}
# 553607  {u'thirtyToEnd': 571.6, u'twentyToThirty': 600...
# 553608  {u'thirtyToEnd': 293.6, u'twentyToThirty': 421...
# 553609  {u'thirtyToEnd': 937.8, u'twentyToThirty': 114...
# 553611  {u'thirtyToEnd': 1044.2, u'twentyToThirty': 56...
# 553612  {u'thirtyToEnd': 0.0, u'twentyToThirty': 387.9...
# 553614  {u'thirtyToEnd': 921.7, u'twentyToThirty': 748...
# 553631  {u'thirtyToEnd': 1504.35, u'twentyToThirty': 7...
# 553632  {u'thirtyToEnd': 1120.45, u'twentyToThirty': 1...
# 553634  {u'thirtyToEnd': 999.25, u'twentyToThirty': 67...
# 553635  {u'twentyToThirty': 1177.4, u'zeroToTen': 239....
# 553637  {u'twentyToThirty': 1006.7, u'zeroToTen': 132....
# 553638  {u'twentyToThirty': 1602.2, u'zeroToTen': 363....
# 553646  {u'thirtyToEnd': 843.0, u'twentyToThirty': 630...
# 553647  {u'thirtyToEnd': 440.8, u'twentyToThirty': 449...
# 553649  {u'thirtyToEnd': 1517.1, u'twentyToThirty': 15...
# 553653  {u'thirtyToEnd': 944.8, u'twentyToThirty': 675...
# 553654  {u'thirtyToEnd': 1591.2, u'twentyToThirty': 60...
# 553656  {u'thirtyToEnd': 1622.0, u'twentyToThirty': 92...
# 553658       {u'zeroToTen': 386.3, u'tenToTwenty': 637.6}
# 553659       {u'zeroToTen': 296.9, u'tenToTwenty': 683.5}
# 553662       {u'zeroToTen': 296.2, u'tenToTwenty': 320.1}
# 553667  {u'thirtyToEnd': 1278.6, u'twentyToThirty': 62...
# 553669  {u'thirtyToEnd': 949.3, u'twentyToThirty': 488...
# 553670  {u'thirtyToEnd': 2324.6, u'twentyToThirty': 11...
#
#                                          goldPerMinDeltas    lane       role  \
# 0       {u'thirtyToEnd': 481.4, u'twentyToThirty': 288...  BOTTOM  DUO_CARRY
# 1       {u'thirtyToEnd': 503.4, u'twentyToThirty': 435...  MIDDLE       SOLO
# 2       {u'thirtyToEnd': 433.6, u'twentyToThirty': 405...     TOP       SOLO
# 5       {u'thirtyToEnd': 476.0, u'twentyToThirty': 292...  MIDDLE       SOLO
# 6       {u'thirtyToEnd': 496.0, u'twentyToThirty': 567...     TOP       SOLO
# 7       {u'thirtyToEnd': 240.4, u'twentyToThirty': 304...  BOTTOM  DUO_CARRY
# 10      {u'thirtyToEnd': 393.6, u'twentyToThirty': 668...  MIDDLE       SOLO
# 11      {u'thirtyToEnd': 343.3, u'twentyToThirty': 419...     TOP       SOLO
# 12      {u'thirtyToEnd': 342.9, u'twentyToThirty': 489...  BOTTOM  DUO_CARRY
# 16           {u'zeroToTen': 200.0, u'tenToTwenty': 339.9}     TOP       SOLO
# 17           {u'zeroToTen': 299.7, u'tenToTwenty': 647.4}  MIDDLE       SOLO
# 19           {u'zeroToTen': 270.5, u'tenToTwenty': 401.3}  BOTTOM  DUO_CARRY
# 20           {u'zeroToTen': 225.6, u'tenToTwenty': 391.3}  BOTTOM  DUO_CARRY
# 22           {u'zeroToTen': 195.5, u'tenToTwenty': 264.9}  MIDDLE       SOLO
# 24           {u'zeroToTen': 232.6, u'tenToTwenty': 333.4}     TOP       SOLO
# 25           {u'zeroToTen': 220.6, u'tenToTwenty': 472.5}  BOTTOM  DUO_CARRY
# 27           {u'zeroToTen': 260.0, u'tenToTwenty': 441.1}  MIDDLE       SOLO
# 29           {u'zeroToTen': 204.9, u'tenToTwenty': 377.8}     TOP       SOLO
# 30      {u'thirtyToEnd': 609.6, u'twentyToThirty': 592...  BOTTOM  DUO_CARRY
# 32      {u'thirtyToEnd': 455.2, u'twentyToThirty': 450...     TOP       SOLO
# 33      {u'thirtyToEnd': 553.0, u'twentyToThirty': 467...  MIDDLE       SOLO
# 35      {u'twentyToThirty': 458.2, u'zeroToTen': 240.2...  BOTTOM  DUO_CARRY
# 36      {u'twentyToThirty': 498.1, u'zeroToTen': 223.9...     TOP       SOLO
# 39      {u'twentyToThirty': 400.7, u'zeroToTen': 222.6...  MIDDLE       SOLO
# 50           {u'zeroToTen': 296.7, u'tenToTwenty': 399.9}  BOTTOM  DUO_CARRY
# 51           {u'zeroToTen': 258.3, u'tenToTwenty': 340.0}  MIDDLE       SOLO
# 53           {u'zeroToTen': 285.2, u'tenToTwenty': 566.7}     TOP       SOLO
# 55      {u'twentyToThirty': 489.9, u'zeroToTen': 239.7...  BOTTOM  DUO_CARRY
# 56      {u'twentyToThirty': 287.8, u'zeroToTen': 237.9...     TOP       SOLO
# 57      {u'twentyToThirty': 290.8, u'zeroToTen': 243.9...  MIDDLE       SOLO
# ...                                                   ...     ...        ...
# 553592       {u'zeroToTen': 200.7, u'tenToTwenty': 329.4}  MIDDLE       SOLO
# 553593       {u'zeroToTen': 190.9, u'tenToTwenty': 324.2}  BOTTOM  DUO_CARRY
# 553594       {u'zeroToTen': 200.4, u'tenToTwenty': 306.4}     TOP       SOLO
# 553601       {u'zeroToTen': 252.2, u'tenToTwenty': 462.6}     TOP       SOLO
# 553602       {u'zeroToTen': 238.9, u'tenToTwenty': 525.6}  BOTTOM  DUO_CARRY
# 553604       {u'zeroToTen': 163.6, u'tenToTwenty': 364.5}  MIDDLE       SOLO
# 553607  {u'thirtyToEnd': 432.4, u'twentyToThirty': 538...  MIDDLE       SOLO
# 553608  {u'thirtyToEnd': 477.4, u'twentyToThirty': 400...  BOTTOM  DUO_CARRY
# 553609  {u'thirtyToEnd': 487.4, u'twentyToThirty': 322...     TOP       SOLO
# 553611  {u'thirtyToEnd': 290.2, u'twentyToThirty': 277...     TOP       SOLO
# 553612  {u'thirtyToEnd': 114.0, u'twentyToThirty': 217...  MIDDLE       SOLO
# 553614  {u'thirtyToEnd': 500.0, u'twentyToThirty': 362...  BOTTOM  DUO_CARRY
# 553631  {u'thirtyToEnd': 512.8, u'twentyToThirty': 404...     TOP       SOLO
# 553632  {u'thirtyToEnd': 253.75, u'twentyToThirty': 34...  MIDDLE       SOLO
# 553634  {u'thirtyToEnd': 423.2, u'twentyToThirty': 530...  BOTTOM  DUO_CARRY
# 553635  {u'twentyToThirty': 243.1, u'zeroToTen': 272.5...  MIDDLE       SOLO
# 553637  {u'twentyToThirty': 405.7, u'zeroToTen': 238.1...  BOTTOM  DUO_CARRY
# 553638  {u'twentyToThirty': 276.2, u'zeroToTen': 260.3...     TOP       SOLO
# 553646  {u'thirtyToEnd': 239.4, u'twentyToThirty': 362...  BOTTOM  DUO_CARRY
# 553647  {u'thirtyToEnd': 281.4, u'twentyToThirty': 335...  MIDDLE       SOLO
# 553649  {u'thirtyToEnd': 233.6, u'twentyToThirty': 378...     TOP       SOLO
# 553653  {u'thirtyToEnd': 302.8, u'twentyToThirty': 298...  MIDDLE       SOLO
# 553654  {u'thirtyToEnd': 500.8, u'twentyToThirty': 276...  BOTTOM  DUO_CARRY
# 553656  {u'thirtyToEnd': 264.6, u'twentyToThirty': 371...     TOP       SOLO
# 553658       {u'zeroToTen': 225.5, u'tenToTwenty': 244.7}  MIDDLE       SOLO
# 553659       {u'zeroToTen': 215.5, u'tenToTwenty': 298.6}     TOP       SOLO
# 553662       {u'zeroToTen': 173.3, u'tenToTwenty': 286.3}  BOTTOM  DUO_CARRY
# 553667  {u'thirtyToEnd': 316.5, u'twentyToThirty': 360...  BOTTOM  DUO_CARRY
# 553669  {u'thirtyToEnd': 298.9, u'twentyToThirty': 318...  MIDDLE       SOLO
# 553670  {u'thirtyToEnd': 264.0, u'twentyToThirty': 486...     TOP       SOLO
#
#                                        xpDiffPerMinDeltas  \
# 0       {u'thirtyToEnd': 288.2, u'twentyToThirty': -67...
# 1       {u'thirtyToEnd': 136.0, u'twentyToThirty': -16...
# 2       {u'thirtyToEnd': 249.4, u'twentyToThirty': 123...
# 5       {u'thirtyToEnd': 124.0, u'twentyToThirty': -14...
# 6       {u'thirtyToEnd': 101.6, u'twentyToThirty': 192...
# 7       {u'thirtyToEnd': 35.5, u'twentyToThirty': -62....
# 10      {u'thirtyToEnd': -136.0, u'twentyToThirty': 16...
# 11      {u'thirtyToEnd': -249.4, u'twentyToThirty': -1...
# 12      {u'thirtyToEnd': -288.2, u'twentyToThirty': 67...
# 16            {u'zeroToTen': -225.1, u'tenToTwenty': 3.4}
# 17            {u'zeroToTen': 26.5, u'tenToTwenty': 290.6}
# 19            {u'zeroToTen': 109.0, u'tenToTwenty': 69.9}
# 20           {u'zeroToTen': -34.8, u'tenToTwenty': -44.7}
# 22          {u'zeroToTen': -59.6, u'tenToTwenty': -202.4}
# 24            {u'zeroToTen': 18.5, u'tenToTwenty': -55.3}
# 25            {u'zeroToTen': 6.1, u'tenToTwenty': 200.85}
# 27            {u'zeroToTen': 54.2, u'tenToTwenty': 224.0}
# 29           {u'zeroToTen': -33.8, u'tenToTwenty': -84.1}
# 30      {u'thirtyToEnd': 258.0, u'twentyToThirty': 133...
# 32      {u'thirtyToEnd': 232.8, u'twentyToThirty': 60....
# 33      {u'thirtyToEnd': 452.8, u'twentyToThirty': -17...
# 35      {u'twentyToThirty': 37.15, u'zeroToTen': 5.95,...
# 36      {u'twentyToThirty': 296.8, u'zeroToTen': -15.6...
# 39      {u'twentyToThirty': -14.5, u'zeroToTen': 97.1,...
# 50           {u'zeroToTen': 5.45, u'tenToTwenty': -54.75}
# 51             {u'zeroToTen': -64.8, u'tenToTwenty': 1.7}
# 53           {u'zeroToTen': 115.3, u'tenToTwenty': 207.3}
# 55      {u'twentyToThirty': -84.3, u'zeroToTen': -2.95...
# 56      {u'twentyToThirty': -412.6, u'zeroToTen': -54....
# 57      {u'twentyToThirty': -296.5, u'zeroToTen': -11....
# ...                                                   ...
# 553592      {u'zeroToTen': -50.9, u'tenToTwenty': -134.2}
# 553593       {u'zeroToTen': -32.8, u'tenToTwenty': 48.85}
# 553594        {u'zeroToTen': -20.6, u'tenToTwenty': 36.6}
# 553601         {u'zeroToTen': 108.8, u'tenToTwenty': 1.4}
# 553602      {u'zeroToTen': -14.45, u'tenToTwenty': 213.5}
# 553604        {u'zeroToTen': -73.1, u'tenToTwenty': 34.4}
# 553607  {u'thirtyToEnd': 166.0, u'twentyToThirty': 137...
# 553608  {u'thirtyToEnd': 210.6, u'twentyToThirty': 80....
# 553609  {u'thirtyToEnd': 213.4, u'twentyToThirty': 239...
# 553611  {u'thirtyToEnd': 241.4, u'twentyToThirty': -10...
# 553612  {u'thirtyToEnd': -514.6, u'twentyToThirty': -2...
# 553614  {u'thirtyToEnd': 79.4, u'twentyToThirty': -80....
# 553631  {u'thirtyToEnd': 90.85, u'twentyToThirty': 119...
# 553632  {u'thirtyToEnd': -60.35, u'twentyToThirty': -7...
# 553634  {u'thirtyToEnd': 28.6, u'twentyToThirty': 140....
# 553635  {u'twentyToThirty': -183.6, u'zeroToTen': 55.2...
# 553637  {u'twentyToThirty': -21.45, u'zeroToTen': 4.7,...
# 553638  {u'twentyToThirty': -133.7, u'zeroToTen': 34.7...
# 553646  {u'thirtyToEnd': -310.85, u'twentyToThirty': 1...
# 553647  {u'thirtyToEnd': -117.3, u'twentyToThirty': -4...
# 553649  {u'thirtyToEnd': -273.4, u'twentyToThirty': 16...
# 553653  {u'thirtyToEnd': 73.6, u'twentyToThirty': -47....
# 553654  {u'thirtyToEnd': -196.8, u'twentyToThirty': -2...
# 553656  {u'thirtyToEnd': -129.6, u'twentyToThirty': 11...
# 553658         {u'zeroToTen': 0.5, u'tenToTwenty': -98.0}
# 553659        {u'zeroToTen': -4.2, u'tenToTwenty': -67.5}
# 553662      {u'zeroToTen': -51.1, u'tenToTwenty': -95.85}
# 553667  {u'thirtyToEnd': -189.0, u'twentyToThirty': -0...
# 553669  {u'thirtyToEnd': -27.5, u'twentyToThirty': 28....
# 553670  {u'thirtyToEnd': -178.5, u'twentyToThirty': 22...
#
#                                            xpPerMinDeltas  \
# 0       {u'thirtyToEnd': 821.5, u'twentyToThirty': 350...
# 1       {u'thirtyToEnd': 676.7, u'twentyToThirty': 546...
# 2       {u'thirtyToEnd': 701.7, u'twentyToThirty': 571...
# 5       {u'thirtyToEnd': 816.8, u'twentyToThirty': 412...
# 6       {u'thirtyToEnd': 435.0, u'twentyToThirty': 568...
# 7       {u'thirtyToEnd': 434.6, u'twentyToThirty': 463...
# 10      {u'thirtyToEnd': 540.7, u'twentyToThirty': 715...
# 11      {u'thirtyToEnd': 452.3, u'twentyToThirty': 447...
# 12      {u'thirtyToEnd': 358.2, u'twentyToThirty': 493...
# 16           {u'zeroToTen': 279.2, u'tenToTwenty': 532.1}
# 17           {u'zeroToTen': 449.9, u'tenToTwenty': 531.0}
# 19           {u'zeroToTen': 335.1, u'tenToTwenty': 439.1}
# 20           {u'zeroToTen': 277.8, u'tenToTwenty': 428.3}
# 22           {u'zeroToTen': 383.1, u'tenToTwenty': 391.7}
# 24           {u'zeroToTen': 478.0, u'tenToTwenty': 550.3}
# 25           {u'zeroToTen': 281.3, u'tenToTwenty': 532.9}
# 27           {u'zeroToTen': 398.7, u'tenToTwenty': 490.7}
# 29           {u'zeroToTen': 415.4, u'tenToTwenty': 507.4}
# 30      {u'thirtyToEnd': 722.4, u'twentyToThirty': 699...
# 32      {u'thirtyToEnd': 586.0, u'twentyToThirty': 615...
# 33      {u'thirtyToEnd': 791.4, u'twentyToThirty': 481...
# 35      {u'twentyToThirty': 526.6, u'zeroToTen': 304.8...
# 36      {u'twentyToThirty': 604.6, u'zeroToTen': 376.6...
# 39      {u'twentyToThirty': 515.8, u'zeroToTen': 411.0...
# 50           {u'zeroToTen': 332.3, u'tenToTwenty': 331.5}
# 51           {u'zeroToTen': 356.4, u'tenToTwenty': 388.2}
# 53           {u'zeroToTen': 466.7, u'tenToTwenty': 611.9}
# 55      {u'twentyToThirty': 505.3, u'zeroToTen': 236.6...
# 56      {u'twentyToThirty': 345.6, u'zeroToTen': 412.2...
# 57      {u'twentyToThirty': 281.4, u'zeroToTen': 396.2...
# ...                                                   ...
# 553592       {u'zeroToTen': 339.9, u'tenToTwenty': 414.9}
# 553593       {u'zeroToTen': 247.9, u'tenToTwenty': 433.8}
# 553594       {u'zeroToTen': 409.7, u'tenToTwenty': 581.8}
# 553601       {u'zeroToTen': 453.6, u'tenToTwenty': 456.4}
# 553602       {u'zeroToTen': 258.6, u'tenToTwenty': 409.0}
# 553604       {u'zeroToTen': 317.2, u'tenToTwenty': 436.2}
# 553607  {u'thirtyToEnd': 603.8, u'twentyToThirty': 539...
# 553608  {u'thirtyToEnd': 653.6, u'twentyToThirty': 448...
# 553609  {u'thirtyToEnd': 542.8, u'twentyToThirty': 539...
# 553611  {u'thirtyToEnd': 706.8, u'twentyToThirty': 324...
# 553612  {u'thirtyToEnd': 0.0, u'twentyToThirty': 124.1...
# 553614  {u'thirtyToEnd': 632.8, u'twentyToThirty': 474...
# 553631  {u'thirtyToEnd': 571.85, u'twentyToThirty': 52...
# 553632  {u'thirtyToEnd': 378.75, u'twentyToThirty': 36...
# 553634  {u'thirtyToEnd': 515.75, u'twentyToThirty': 57...
# 553635  {u'twentyToThirty': 382.2, u'zeroToTen': 417.4...
# 553637  {u'twentyToThirty': 623.3, u'zeroToTen': 314.6...
# 553638  {u'twentyToThirty': 391.1, u'zeroToTen': 411.4...
# 553646  {u'thirtyToEnd': 274.8, u'twentyToThirty': 434...
# 553647  {u'thirtyToEnd': 392.8, u'twentyToThirty': 365...
# 553649  {u'thirtyToEnd': 256.5, u'twentyToThirty': 433...
# 553653  {u'thirtyToEnd': 506.4, u'twentyToThirty': 320...
# 553654  {u'thirtyToEnd': 505.2, u'twentyToThirty': 349...
# 553656  {u'thirtyToEnd': 302.6, u'twentyToThirty': 462...
# 553658       {u'zeroToTen': 439.5, u'tenToTwenty': 395.4}
# 553659       {u'zeroToTen': 434.6, u'tenToTwenty': 440.8}
# 553662       {u'zeroToTen': 232.3, u'tenToTwenty': 340.5}
# 553667  {u'thirtyToEnd': 462.3, u'twentyToThirty': 463...
# 553669  {u'thirtyToEnd': 411.4, u'twentyToThirty': 345...
# 553670  {u'thirtyToEnd': 307.4, u'twentyToThirty': 636...
#
#                            name
# 0           Twitch's Commanders
# 1        Nocturne's Pyromancers
# 2                Zed's Warriors
# 5        Nocturne's Pyromancers
# 6         Garen's Battlemasters
# 7            Irelia's Assassins
# 10       Kassadin's Blightlords
# 11          Lux's Spellbreakers
# 12                Talon's Fists
# 16        Ezreal's Shadehunters
# 17         Malphite's Urfriders
# 19        Malphite's Gladiators
# 20                Talon's Fists
# 22       Tryndamere's Commandos
# 24         Zilean's Masterminds
# 25                Talon's Fists
# 27         Graves's Inquisitors
# 29               Sona's Rangers
# 30                Talon's Fists
# 32            Soraka's Duelists
# 33              Udyr's Alliance
# 35                Talon's Fists
# 36      Caitlyn's Swashbucklers
# 39                Maokai's Army
# 50                Talon's Fists
# 51          Leona's Spellswords
# 53                  Fizz's Army
# 55                Talon's Fists
# 56           Cho'Gath's Dervish
# 57        Graves's Executioners
# ...                         ...
# 553592       Cho'Gath's Zealots
# 553593      Kassadin's Patriots
# 553594         Wukong's Dragons
# 553601      Volibear's Paragons
# 553602     Zilean's Masterminds
# 553604     Hecarim's Commanders
# 553607       Draven's Urfriders
# 553608           Lux's Sentries
# 553609    Twisted Fate's Rogues
# 553611         Teemo's Marksmen
# 553612   Cassiopeia's Outriders
# 553614         Shaco's Captains
# 553631         Kayle's Alliance
# 553632        Xerath's Brigands
# 553634         Trundle's Chosen
# 553635     Talon's Necromancers
# 553637            Swain's Fists
# 553638       Akali's Commanders
# 553646         Brand's Patriots
# 553647           Ahri's Hunters
# 553649        Volibear's Chosen
# 553653         Vayne's Rageborn
# 553654            Jax's Hunters
# 553656       Morgana's Villains
# 553658        Garen's Crusaders
# 553659     Taric's Dawnbringers
# 553662         Rumble's Snipers
# 553667       Anivia's Cavaliers
# 553669       Skarner's Sentries
# 553670          Kayle's Lancers
#
# [251187 rows x 12 columns]
